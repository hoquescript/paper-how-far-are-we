# %%
import pandas as pd

# %%
java = pd.read_csv("../data/java.csv")
python = pd.read_csv("../data/python.csv")

# %%
print(java.shape)
print(python.shape)
# Out:
# (50000, 3)
# (50000, 3)

# %%
print(java.columns)
print(python.columns)
# Out:
# Index(['language', 'code', 'label'], dtype='object')
# Index(['language', 'code', 'label'], dtype='object')

# %%
print(java['label'].value_counts())
print(python['label'].value_counts())
# Out:
# label
# 1    25031
# 0    24969
# Name: count, dtype: int64
# label
# 1    25024
# 0    24976
# Name: count, dtype: int64
